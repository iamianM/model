# %%
import alpaca_trade_api as tradeapi
import pandas as pd

# %%
api = tradeapi.REST('PKRDE1FPPKM9I0F7832V', 'ViKp56alhPBUf5pZtnaWBndoN1C9aE4StCrkTTPT', 
                    base_url='https://paper-api.alpaca.markets') # or use ENV Vars shown below
account = api.get_account()
api.list_positions()
# Out:
# []

# %%
api.get_barset?

# %%
NY = 'America/New_York'
start=pd.Timestamp('2021-02-19', tz=NY).isoformat()
end=pd.Timestamp('2021-02-20', tz=NY).isoformat()
df = api.get_barset(['ACAC'], 'minute', limit=1000, start=start, end=end).df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 117 entries, 2021-02-19 09:30:00-05:00 to 2021-02-19 15:59:00-05:00
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (ACAC, open)    117 non-null    float64
#  1   (ACAC, high)    117 non-null    float64
#  2   (ACAC, low)     117 non-null    float64
#  3   (ACAC, close)   117 non-null    float64
#  4   (ACAC, volume)  117 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 5.5 KB

# %%
pd.set_option('display.max_rows', 1000)
df
# Out:
#                              ACAC
#                              open    high     low   close volume
# time
# 2021-02-19 09:30:00-05:00  10.790  10.790  10.735  10.735    221
# 2021-02-19 09:31:00-05:00  10.760  10.760  10.760  10.760    100
# 2021-02-19 09:32:00-05:00  10.735  10.800  10.735  10.800    400
# 2021-02-19 09:34:00-05:00  10.800  10.800  10.800  10.800    199
# 2021-02-19 09:36:00-05:00  10.800  10.800  10.800  10.800    100
# 2021-02-19 10:25:00-05:00  10.870  10.870  10.870  10.870    100
# 2021-02-19 10:52:00-05:00  10.870  10.870  10.870  10.870    268
# 2021-02-19 11:09:00-05:00  10.785  10.785  10.785  10.785    100
# 2021-02-19 11:11:00-05:00  10.780  10.780  10.780  10.780    200
# 2021-02-19 11:12:00-05:00  10.780  10.780  10.780  10.780    100
# 2021-02-19 11:13:00-05:00  10.780  10.780  10.780  10.780    200
# 2021-02-19 11:14:00-05:00  10.780  10.780  10.780  10.780    200
# 2021-02-19 11:15:00-05:00  10.780  10.780  10.780  10.780    200
# ...

# %%
hists['ACAC_2021-02-19']
# Out:
#                             open   high    low  close   volume   vwap    label
# timestamp
# 2021-02-19 09:31:00-05:00  10.69  10.74  10.69  10.74  15254.0  10.70  nothing
# 2021-02-19 09:32:00-05:00  10.76  10.76  10.76  10.76    304.0  10.71  nothing
# 2021-02-19 09:33:00-05:00  10.77  10.78  10.77  10.78    830.0  10.71  nothing
# 2021-02-19 09:34:00-05:00  10.78  10.78  10.78  10.78    605.0  10.72  nothing
# 2021-02-19 09:35:00-05:00  10.78  10.78  10.78  10.78    709.0  10.72  nothing
# 2021-02-19 09:36:00-05:00  10.80  10.81  10.78  10.81   3078.0  10.73  nothing
# 2021-02-19 09:38:00-05:00  10.85  10.87  10.83  10.83   4057.0  10.75  nothing
# 2021-02-19 09:43:00-05:00  10.88  10.88  10.88  10.88    185.0  10.75     sell
# 2021-02-19 09:45:00-05:00  10.87  10.88  10.85  10.88    540.0  10.76  nothing
# 2021-02-19 09:46:00-05:00  10.87  10.87  10.87  10.87    467.0  10.77  nothing
# 2021-02-19 09:47:00-05:00  10.87  10.87  10.87  10.87    302.0  10.77  nothing
# ...

# %%
from day_trade import login_webull, get_hists
hists = get_hists(path='./daily_stock_data/')

# %%
sum([idx not in hists['ACAC_2021-02-19'].index for idx in df.index]), sum([idx not in df.index for idx in hists['ACAC_2021-02-19'].index])
# Out:
# (25, 188)
